# %%
name = "Koushiki"
age = 21
cgpa = 8.04

print(name)
print(age)
print(cgpa)
# Out:
# Koushiki
# 21
# 8.04

# %%
ages = [45, 54, 39, 60, 35]

print(ages)
print(ages[0])
print(ages[-1])
# Out:
# [45, 54, 39, 60, 35]
# 45
# 35

# %%
ages.append(70)

# %%
print(ages)
# Out:
# [45, 54, 39, 60, 35, 70]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import zipfile
import os

columns = [
    "age",
    "sex",
    "cp",
    "trestbps",
    "chol",
    "fbs",
    "restecg",
    "thalach",
    "exang",
    "oldpeak",
    "slope",
    "ca",
    "thal",
    "target"
]

zip_file_path = "/content/heart+disease.zip"
extract_dir = "/content/extracted_data"
csv_file_in_zip = "processed.cleveland.data"

try:
    # Create directory for extraction if it doesn't exist
    os.makedirs(extract_dir, exist_ok=True)

    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extract(csv_file_in_zip, extract_dir)

    csv_path = os.path.join(extract_dir, csv_file_in_zip)
    df = pd.read_csv(
        csv_path,
        names=columns,
        na_values="?"
    )
    print(df)

except zipfile.BadZipFile:
    print(f"Error: The file '{zip_file_path}' is not a valid ZIP file. Please check the file integrity or re-upload it.")
except FileNotFoundError:
    print(f"Error: The file '{zip_file_path}' was not found. Please ensure it's uploaded correctly.")
except KeyError:
    print(f"Error: The file '{csv_file_in_zip}' was not found inside '{zip_file_path}'.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
print(df.head())
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       2
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
# Display last 5 rows
print(df.tail())
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  target
# 298    2.0  0.0   7.0       1
# 299    2.0  2.0   7.0       2
# 300    2.0  1.0   7.0       3
# 301    2.0  1.0   3.0       1
# 302    1.0  NaN   3.0       0

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (303, 14)

# %%
print("Column names:")
print(df.columns)
# Out:
# Column names:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  target    303 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 33.3 KB

# %%
print(df.describe())
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
print(df[["age", "chol", "target"]])
# Out:
#       age   chol  target
# 0    63.0  233.0       0
# 1    67.0  286.0       2
# 2    67.0  229.0       1
# 3    37.0  250.0       0
# 4    41.0  204.0       0
# ..    ...    ...     ...
# 298  45.0  264.0       1
# 299  68.0  193.0       2
# 300  57.0  131.0       3
# 301  57.0  236.0       1
# 302  38.0  175.0       0
#
# [303 rows x 3 columns]

# %%
older_patients = df[df["age"] > 50]

print(older_patients)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 296  59.0  1.0  4.0     164.0  176.0  1.0      2.0     90.0    0.0      1.0
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
high_cholesterol = df[df["chol"] > 200]

print(high_cholesterol)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 290  67.0  1.0  3.0     152.0  212.0  0.0      2.0    150.0    0.0      0.8
# 291  55.0  0.0  2.0     132.0  342.0  0.0      0.0    166.0    0.0      1.2
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
result = df[
    (df["age"] > 50) &
    (df["chol"] > 200)
]

print(result)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 289  56.0  1.0  2.0     120.0  240.0  0.0      0.0    169.0    0.0      0.0
# 290  67.0  1.0  3.0     152.0  212.0  0.0      2.0    150.0    0.0      0.8
# 291  55.0  0.0  2.0     132.0  342.0  0.0      0.0    166.0    0.0      1.2
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
import numpy as np

# %%
average_age = np.mean(df["age"])

print("Average age:", average_age)
# Out:
# Average age: 54.43894389438944

# %%
print("Minimum age:", np.min(df["age"]))
print("Maximum age:", np.max(df["age"]))
# Out:
# Minimum age: 29.0
# Maximum age: 77.0

# %%
average_chol = np.mean(df["chol"])

print("Average cholesterol:", average_chol)
# Out:
# Average cholesterol: 246.69306930693068

# %%
print("Minimum cholesterol:", np.min(df["chol"]))
print("Maximum cholesterol:", np.max(df["chol"]))
# Out:
# Minimum cholesterol: 126.0
# Maximum cholesterol: 564.0

# %%
median_age = np.median(df["age"])

print("Median age:", median_age)
# Out:
# Median age: 56.0

# %%
std_age = np.std(df["age"])

print("Standard deviation of age:", std_age)
# Out:
# Standard deviation of age: 9.023734831198377

# %%
age_array = np.array(df["age"])

count = np.sum(age_array > 50)

print("Patients older than 50:", count)
# Out:
# Patients older than 50: 209

# %%
chol_array = np.array(df["chol"])

count = np.sum(chol_array > 200)

print("Patients with cholesterol above 200:", count)
# Out:
# Patients with cholesterol above 200: 253

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["age"], bins=10)

plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.title("Age Distribution of Patients")

plt.show()

# %%
plt.hist(df["chol"], bins=10)

plt.xlabel("Cholesterol")
plt.ylabel("Number of Patients")
plt.title("Cholesterol Distribution")

plt.show()

# %%
plt.scatter(df["age"], df["chol"])

plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.title("Age vs Cholesterol")

plt.show()

# %%
target_counts = df["target"].value_counts()

print(target_counts)
plt.bar(target_counts.index.astype(str), target_counts.values)

plt.xlabel("Heart Disease Target")
plt.ylabel("Number of Patients")
plt.title("Heart Disease Target Distribution")

plt.show()
# Out:
# target
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: count, dtype: int64

# %%
plt.scatter(df["age"], df["thalach"])

plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.title("Age vs Maximum Heart Rate")

plt.show()
